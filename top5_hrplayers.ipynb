# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import calendar

# %%
judge_2022 = pd.read_csv('judge_2022_daily_stats.csv')
riley_2022 = pd.read_csv('riley_2022_daily_stats.csv')
alonso_2022 = pd.read_csv('alonso_2022_daily_stats.csv')
schwarber_2022 = pd.read_csv('schwarber_2022_daily_stats.csv')
trout_2022 = pd.read_csv('trout_2022_daily_stats.csv')
judge_2022.head()
# Out:
#          Date            Home Tm             Away Tm  PA  AB  R  H  2B  3B
# 0  2022-04-08   New York Yankees      Boston Red Sox   5   5  1  2   1   0  \
# 1  2022-04-09   New York Yankees      Boston Red Sox   4   3  1  0   0   0
# 2  2022-04-10   New York Yankees      Boston Red Sox   5   5  0  2   0   0
# 3  2022-04-11   New York Yankees   Toronto Blue Jays   4   3  0  0   0   0
# 4  2022-04-12   New York Yankees   Toronto Blue Jays   4   4  0  1   1   0
#
#    HR  ...  BB  SO  SB  CS  HBP    AVG    OBP    SLG    OPS  day_of_week
# 0   0  ...   0   1   0   0    0  0.400  0.400  0.600  1.000       Friday
# 1   0  ...   1   0   0   0    0  0.250  0.333  0.375  0.708     Saturday
# 2   0  ...   0   2   1   0    0  0.308  0.357  0.385  0.742       Sunday
# 3   0  ...   1   2   0   0    0  0.250  0.333  0.313  0.646       Monday
# 4   0  ...   0   0   0   0    0  0.250  0.318  0.350  0.668      Tuesday
#
# [5 rows x 21 columns]

# %%
judge_2022['Month'] = pd.to_datetime(judge_2022['Date']).dt.month
month_names = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August',
               9: 'September', 10: 'October'}
judge_2022['Month'] = judge_2022['Month'].map(month_names)
month_order = ['April', 'May', 'June', 'July', 'August', 'September', 'October']
judge_2022['Month'] = pd.Categorical(judge_2022['Month'], categories=month_order, ordered=True)

# Create a pivot table to calculate the number of home runs for each day of the week and month
pivot_table = judge_2022.pivot_table(index='day_of_week', columns='Month', values='HR', aggfunc='sum')

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, fmt='.0f', cmap='BuPu',  cbar=False)

# Set the title and labels
plt.title('Aaron Judge Home Runs by Day and Month')
plt.xlabel('Month')
plt.ylabel('Day of Week')

# Display the heatmap
plt.show()

# %%
judge_2022['Month'] = pd.to_datetime(judge_2022['Date']).dt.month
month_names = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'August',
               9: 'September', 10: 'October'}
judge_2022['Month'] = judge_2022['Month'].map(month_names)
month_order = ['April', 'May', 'June', 'July', 'August', 'September', 'October']
judge_2022['Month'] = pd.Categorical(judge_2022['Month'], categories=month_order, ordered=True)

# Create a pivot table to calculate the number of home runs for each day of the week and month
pivot_table = judge_2022.pivot_table(index='day_of_week', columns='Month', values='AVG', aggfunc='mean')

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, fmt='.3f', cmap='Spectral',  cbar=True)

# Set the title and labels
plt.title('Aaron Judge Home Runs by Day and Month')
plt.xlabel('Month')
plt.ylabel('Day of Week')

# Display the heatmap
plt.show()
